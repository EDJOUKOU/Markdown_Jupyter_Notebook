# %% [markdown]
# # My first Jupyter notebook project

# %% [markdown]
# Name: **EDJOUKOU Yessoh** \
# Current Occupation: **PhD Candidate in Management Sciences and Engineering** \
# Desired Occupation: **Data Sciencist** \
# Country of Origin: **Ivory Coast, West Africa**

# %% [markdown]
# ### "Why am i attracted to data sciences?"
#
# <div class="alert alert-block alert-info">
# <b></b>
# I am interested in data science because it is the sexiest job of the 21st century. More and more businesses and companies are requiring this expertise. On the other hand, it enables for a better problem visualization and presentation. In a nutshell, data science tells a coherent story with data and optimize the solutions or measures to be taken to tackle an issue. Whether you are aiming at taking a job or being an entrpreneur, data sciences will equip you with the right skills to make informed decisions.
# </div>

# %% [markdown]
# ### Create a simple variable and print out the value

# %%
IBM_Employees_List = ['Charles', 'Irina', 'Peter', 'Andrew', 'Mary']
print(IBM_Employees_List)
# Out:
# ['Charles', 'Irina', 'Peter', 'Andrew', 'Mary']

# %% [markdown]
# ### Access an element in the list previously created

# %%
IBM_Employees_List[0]
# Out:
# 'Charles'

# %%
IBM_Employees_List[-1]
# Out:
# 'Mary'

# %% [markdown]
# ### Change a name in the list

# %%
IBM_Employees_List[0]='Joe'
print(IBM_Employees_List)
# Out:
# ['Joe', 'Irina', 'Peter', 'Andrew', 'Mary']

# %% [markdown]
# ### Key skills to learn in the data sciences curriculum include:

# %% [markdown]
# 1. What is data sciences?
# 2. Open source tools for data sciences
# 3. Data Sciences Methodology
# 3. Python for data sciences
# 4. Databases and SQL
# 5. Data analysis with Python
# 6. Data visualization with Python
# 7. Machine Learning

# %% [markdown]
# #### An interesting course to get started with data sciences is the IBM data science Professional Certificate whose link is right below:

# %% [markdown]
# <https://www.coursera.org/professional-certificates/ibm-data-science?>

# %% [markdown]
# ### Create a basic table

# %% [markdown]
# |Employees_Name|     Role     |Monthly Salary($US)|
# |--------------|:-------     :|------------------:|
# |     Joe      |   Intern     |        1.5K       |
# |    Irina     |  Soft.Eng    |        8k         |
# |    Peter     |      Hr      |         4k        |
# |    Andrew    |     Sales    |        3.5k       |
# |    Mary      |Data Scientist|        7.5k       |

# %% [markdown]
# ### Input a beautiful picture

# %% [markdown]
# ![Renewable-Energy4.jpg](attachment:Renewable-Energy4.jpg)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b></b> THANK YOU SO MUCH!
# </div>
